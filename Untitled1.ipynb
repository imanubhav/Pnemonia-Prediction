# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
def imag(ix):
    im=Image.open('./chest_xray/test/PNEUMONIA/'+ix)
    print(im.size)
    
    implot=plt.imshow(im)
    plt.show()

# %%
imag('person1_virus_8.jpeg')
imag('person1_virus_9.jpeg')
# Out:
# (960, 544)
# (856, 552)
